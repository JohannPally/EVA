# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/wangyaohui/Desktop/everything/cs@illinois/ms_research/EXERCISE/exercise_code/stm32wb55_exercise/stm32_wb55_exercise_dev/Data_process'

# %%
df = pd.read_csv('/Users/wangyaohui/Desktop/everything/cs@illinois/ms_research/EXERCISE/exercise_code/stm32wb55_exercise/stm32_wb55_exercise_dev/Data_logging/yuxuan_log.txt', sep="' ", header=None)

# %%
df
# Out:
#              0         1         2         3         4         5          6   \
# 0     -0.007442 -1.020713  0.079239  0.345625  0.131250 -0.463750  -0.650395
# 1     -0.008052 -1.017724  0.074420  0.078750  0.144375 -0.415625  -0.650395
# 2     -0.007503 -1.022238  0.072224  0.310625  0.113750 -0.441875  -0.650395
# 3     -0.003538 -1.018456  0.076677  0.455000  0.161875 -0.288750  -0.650395
# 4     -0.007808 -1.020713  0.076677  0.358750  0.043750 -0.385000  -0.650395
# ...         ...       ...       ...       ...       ...       ...        ...
# 1776   0.035929 -1.012539 -0.058133  0.393750  0.113750 -0.240625  -0.650395
# 1777   0.038430 -1.019310 -0.057828  0.371875  0.175000 -0.433125  -0.650395
# 1778   0.036295 -1.015528 -0.057828  0.380625  0.249375 -0.433125  -0.650395
# 1779   0.035807 -1.016565 -0.057523  0.275625  0.175000 -0.350000  -0.650395
# 1780   0.036905 -1.023641 -0.058987  0.253750 -0.004375 -0.428750  -0.650395
#
# ...

# %%
df.columns = ["xl_x: g", "xl_y: g", "xl_z: g", "gr_x: deg/s", "gr_y: deg/s", "gr_z: deg/s", "mg_x/gauss", "mg_y/gauss", "mg_z/gauss", "orient_x/deg", "orient_y/deg", "orient_z/deg", "pos_x/m", "pos_y/m", "pos_z/m"]

# %%
df
# Out:
#         xl_x: g   xl_y: g   xl_z: g  gr_x: deg/s  gr_y: deg/s  gr_z: deg/s  \
# 0     -0.007442 -1.020713  0.079239     0.345625     0.131250    -0.463750
# 1     -0.008052 -1.017724  0.074420     0.078750     0.144375    -0.415625
# 2     -0.007503 -1.022238  0.072224     0.310625     0.113750    -0.441875
# 3     -0.003538 -1.018456  0.076677     0.455000     0.161875    -0.288750
# 4     -0.007808 -1.020713  0.076677     0.358750     0.043750    -0.385000
# ...         ...       ...       ...          ...          ...          ...
# 1776   0.035929 -1.012539 -0.058133     0.393750     0.113750    -0.240625
# 1777   0.038430 -1.019310 -0.057828     0.371875     0.175000    -0.433125
# 1778   0.036295 -1.015528 -0.057828     0.380625     0.249375    -0.433125
# 1779   0.035807 -1.016565 -0.057523     0.275625     0.175000    -0.350000
# 1780   0.036905 -1.023641 -0.058987     0.253750    -0.004375    -0.428750
#
# ...

# %%
from pathlib import Path  
filepath = Path('/Users/wangyaohui/Desktop/everything/cs@illinois/ms_research/EXERCISE/exercise_code/stm32wb55_exercise/stm32_wb55_exercise_dev/Data_logging/yuxuan_log.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)
